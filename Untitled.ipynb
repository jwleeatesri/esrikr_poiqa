# %%
import pandas as pd

# %%
dw = pd.read_csv("dw_poi_all.csv")

# %%
dw[dw["subcategory"] == "Highway Exit"]
# Out:
#           OID_        id       name name_alias                  name_eng  \
# 23632    23633  27550906     청라IC출구        NaN          Cheongna IC exit
# 32817    32818  27548903    북청라IC출구        NaN       Bukcheongna IC exit
# 39835    39836  27553706     청라IC출구        NaN          Cheongna IC exit
# 41202    41203  27553372     신천IC출구        NaN         Shincheon IC exit
# 66316    66317  27550643     영종IC출구        NaN         Yeongjong IC exit
# 86010    86011  27552382  검단.양촌IC출구        NaN  Geomdan/Yangchon IC exit
# 143325  143326  27553790    남청라IC출구        NaN       Namcheongna IC exit
# 146026  146027  27553719    북인천IC출구        NaN        Bukincheon IC exit
#
#                     category   subcategory         lon        lat country  \
# 23632   Travel and Transport  Highway Exit  126.669492  37.570240    대한민국
# 32817   Travel and Transport  Highway Exit  126.628130  37.559710    대한민국
# 39835   Travel and Transport  Highway Exit  126.663182  37.567963    대한민국
# ...
